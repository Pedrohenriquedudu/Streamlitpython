# %% [markdown]
# <a href="https://colab.research.google.com/github/Pedrohenriquedudu/Streamlitpython/blob/main/C%C3%B3pia_de_CONFIG_SWT_DATACOM_EDD_2104_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##### CONFIG SWT_DATACOM_EDD_2104 #####

# %%
# SWT_DATACOM


Vendor = "SWT_DATACOM" #@param ["SWT_DATACOM", "SWT_CORIANT"]
Action = "configurar" #@param ["deletar", "configurar"]
Hostname_SWT = "M-BR-SOC-AS-DAT-SWT231"  #@param {type:"string"}
Hostname_Eqp_central = "M-BR-SOC-AS-SWA-01"  #@param {type:"string"}
IP_Eqp_central = "10.81.197.2"  #@param {type:"string"}
Porta_Eqp_central = "5/7"  #@param {type:"string"}
Nome_Cliente = "VIVO_BGV"  #@param {type:"string"}
Velocidade_UPlink =  "1G" #@param ["1G", "10G", "40G", "100G"]
Meio_de_atendimento = "FIBRA" #@param ["FIBRA", "RADIO", "DWDM", "SDH"]
Int_Uplink =  "ethernet 1/1" #@param ["ethernet 1/1", "ethernet 1/2", "ethernet 1/3", "ethernet 1/4"]
Vlan_GER = "3"  #@param {type:"string"}
IP_GER = "10.217.32.43/25" #@param {type:"string"}
Gateway = "10.217.32.1"  #@param {type:"string"}
Vlan_Cliente ="200" #@param {type:"string"}
Int_Cliente = "ethernet 1/5"  #@param ["ethernet 1/5","ethernet 1/6","ethernet 1/7","ethernet 1/8"]
Produto = "VPN" #@param ["VPN", "IPD", "SIP", "L2L"]
Velocidade = "100M" #@param {type:"string"}
ATP_ID = "1725364" #@param {type:"string"}
LP = "115073223224392" #@param {type:"string"}
Rate_in = "102400"  #@param {type:"string"}
Rate_out ="102400" #@param {type:"string"}


print("# "+Vendor+ " " + Action+"\n")




# SWT_DATACOM -----------------------------------------------------------------------

if Vendor == "SWT_DATACOM" and Action == "configurar":
  print("configure")
  print("#")
  print("hostname",(Hostname_SWT))
  print("#")
  print("no username guest")
  print("no ip snmp-server community public")
  print("no remote-devices enable")
  print("terminal timeout 300")
  print("#")
  print("username admin access-level 15")
  print("username admin password 7 765634b9a7a0ea75278b23ecd66a4a99f30a62a3")
  print("username txn1 access-level 15")
  print("username txn1 password 7 7b767b39ebedfaa1a42c487344e97c0b6cab7ad6")
  print("#")
  print("banner login")
  print("~")
  print(" ")
  print("################################################################")
  print("#      ATENCAO: ACESSO PERMITIDO PARA PESSOAL AUTORIZADO.      #")
  print("#                DESCONECTE-SE IMEDIATAMENTE                   #")
  print("# ATTENTION: AUTHORIZED PERSONAL ONLY. DISCONNECT IMMEDIATELY. #")
  print("################################################################")
  print(" ")
  print("~")
  print("cpu-dos-protect rate-limit global 150")
  print("#")
  print("interface vlan 2")
  print("set-member untagged ethernet all")
  print("#")
  print("interface vlan 1")
  print("no name")
  print("no set-member")
  print("no ip address")
  print("#")
  print("vlan qinq")
  print("#")
  print("interface vlan",Vlan_GER)
  print("name GER"+"_"+str(Hostname_Eqp_central)+"_GI_"+str(Porta_Eqp_central))
  print("ip adress",(IP_GER))
  print("set-member tagged",(Int_Uplink))
  print("#")
  print("interface vlan",(Vlan_Cliente))
  print("name " +str(Produto)+"_"+str(Nome_Cliente)+"_"+str(Velocidade)+"_"+str(ATP_ID))
  print("set-member tagged",(Int_Uplink))
  print("set-member untagged",(Int_Cliente))
  print("#")
  print("cpu-dos-protect rate-limit global 150")
  print("vlan-group 1")
  print("vlan-group 1 vlan all")
  print("#")
  print("interface",(Int_Uplink))
  print("description IP_ULK"+"#"+str(Meio_de_atendimento)+"#"+str(Hostname_Eqp_central)+"#"+str(IP_Eqp_central)+"#"+str(Porta_Eqp_central)+"#"+str(Velocidade_UPlink)+"#")
  print("no negotiation")
  print("speed-duplex 1000full")
  print("no spanning-tree 1")
  print("no switchport storm-control broadcast")
  print("no switchport storm-control multicast")
  print("no switchport storm-control dlf")
  print("switchport mtu 9100")
  print("no oam")
  print("switchport qinq internal")
  print("no shutdown")
  print("#")
  print("#")
  print("interface",(Int_Cliente))
  print("description SRV"+"_"+str(Produto)+"#"+str(Meio_de_atendimento)+"#"+str(Nome_Cliente)+"#"+str(Velocidade)+"#"+str(ATP_ID)+"#"+str(LP)+"#"+"CPE_CLIENTE#")
  print("no shut")
  print("rate-limit input rate",(Rate_in),"burst 512")
  print("rate-limit output rate",(Rate_out),"burst 512")
  print("spanning-tree restricted-tcn")
  print("no spanning-tree 1")
  print("switchport native vlan",(Vlan_Cliente))
  print("switchport qinq external")
  print("no switchport storm-control broadcast")
  print("no switchport storm-control multicast")
  print("no switchport storm-control dlf")
  print("switchport mtu 9100")
  print("#")
  print("no remote-devices enable")
  print("remote-devices enable ethernet range 1/1 1/4")
  print("ip default-gateway",(Gateway))
  print("#")
  print("ip telnet server")
  print("ip http server")
  print("ip http secure-server")
  print("ip ssh host-key generate")
  print("ip ssh server")
  print("#")
  print("ip snmp-server")
  print("ip snmp-server community 701hHg61 ro")
  print("ip snmp-server community g3rd@tSWT ro")
  print("ip snmp-server community GESTION ro")
  print("ip snmp-server community G34@T@c5M rw")
  print("ip snmp-server community SMART ro")
  print("ip snmp-server traps dying-gasp")
  print("ip snmp-server host 187.100.227.70 version 2c GESTION")
  print("ip snmp-server host 187.100.21.193 version 2c GESTION")
  print("ip snmp-server host 200.204.1.89 version 2c G34@T@c5M")
  print("ip snmp-server host 200.204.1.91 version 2c G34@T@c5M")
  print("#")
  print("management http-client 200.204.1.0/24")
  print("management snmp-client 200.204.1.0/24")
  print("management snmp-client 201.93.48.224/27")
  print("management snmp-client 187.100.225.0/22")
  print("management snmp-client 187.100.21.193/32")
  print("management ssh-client 200.204.1.0/24")
  print("management snmp-client 186.239.229.152/29")
  print("#")
  print("logging history ram 7")
  print("logging history flash 6")
  print("logging trap 7")
  print("logging host 200.153.1.138")
  print("logging host 200.204.1.106")
  print("logging host 187.100.227.70")
  print("logging host 187.100.221.193")
  print("logging commands to syslog")
  print("#")
  print("sntp client")
  print("sntp server 200.204.1.103")
  print("sntp server 200.204.1.104")
  print("#")
  print("spanning-tree 1")
  print("spanning-tree 1 vlan-group 1")
  print("#")
  print("clock timezone Brasilia -3")
  print("#")
  print("meter new mode flow rate-limit 128 burst 128 remark BROADCAST_VLAN_GERENCIA")
  print("meter new mode flow rate-limit 128 burst 128 remark MULTICAST_VLAN_GERENCIA")
  print("#")
  print("filter new action red-deny match destination-mac host FF-FF-FF-FF-FF-FF match vlan 3 ingress ethernet all meter 1 priority 0 remark BROADCAST_VLAN_GERENCIA")
  print("filter new action red-deny match destination-mac 01-00-00-00-00-00 01-00-00-00-00-00 match vlan 3 ingress ethernet all  meter 2 priority 0 remark MULTICAST_VLAN_GERENCIA")
  print("#")
  print("filter new action 802.1p 6 match vlan 3 ingress ethernet all priority 8")
  print("#")
  print("exit")
  print("copy running-config startup-config 1")
  print("copy running-config startup-config 2")
  print("#")
# Out:
# # SWT_DATACOM configurar
#
# configure
# #
# hostname M-BR-SOC-AS-DAT-SWT231
# #
# no username guest
# no ip snmp-server community public
# no remote-devices enable
# terminal timeout 300
# #
# username admin access-level 15
# username admin password 7 765634b9a7a0ea75278b23ecd66a4a99f30a62a3
# username txn1 access-level 15
# username txn1 password 7 7b767b39ebedfaa1a42c487344e97c0b6cab7ad6
# #
# banner login
# ~
#
# ################################################################
# #      ATENCAO: ACESSO PERMITIDO PARA PESSOAL AUTORIZADO.      #
# #                DESCONECTE-SE IMEDIATAMENTE                   #
# # ATTENTION: AUTHORIZED PERSONAL ONLY. DISCONNECT IMMEDIATELY. #
# ################################################################
#
# ~
# cpu-dos-protect rate-limit global 150
# #
# interface vlan 2
# set-member untagged ethernet all
# #
# interface vlan 1
# no name
# no set-member
# no ip address
# #
# vlan qinq
# #
# interface vlan 3
# ...
